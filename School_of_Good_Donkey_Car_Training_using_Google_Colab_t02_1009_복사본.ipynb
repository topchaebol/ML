# %% [markdown]
# <a href="https://colab.research.google.com/github/topchaebol/ML/blob/master/School_of_Good_Donkey_Car_Training_using_Google_Colab_t02_1009_%EB%B3%B5%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Donkey Car Colab with Accelerated Hardware (Tensorflow GPU)
#
# This notebook is to quickly train your donkey car or self driving RC car model using Google Colab.

# %% [markdown]
# # Install TensorFlow 1.13.1

# %%
# !pip install tensorflow-gpu==1.13.1
# Out:
# ...
#      |████████████████████████████████| 345.2MB 46kB/s
# ...
#      |████████████████████████████████| 368kB 35.4MB/s
# ...
#      |████████████████████████████████| 3.2MB 38.0MB/s
# ...
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 1.13.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.13.0 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
# ...

# %% [markdown]
# # Check GPU allocation
# If "Found GPU at: / device: GPU: 0" is displayed, the GPU is ready to use.

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Git Clone the donkey respository

# %%
# !git clone https://github.com/autorope/donkeycar.git donkey
# Out:
# Cloning into 'donkey'...
# remote: Enumerating objects: 11549, done.
# remote: Total 11549 (delta 0), reused 0 (delta 0), pack-reused 11549
# Receiving objects: 100% (11549/11549), 59.10 MiB | 11.91 MiB/s, done.
# Resolving deltas: 100% (7233/7233), done.

# %% [markdown]
# # Install donkey car

# %%
# !pip3 install -e donkey
# Out:
# Obtaining file:///content/donkey
# ...
#      |████████████████████████████████| 102kB 2.7MB/s
# ...
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.5.0-cp36-none-any.whl size=61416 sha256=d536f6b815afc3f5254e6975f0ccb50457c351adb61bc17fd0612c4ce9d1e2fb
#   Stored in directory: /root/.cache/pip/wheels/02/94/6c/8474137cb7a5a3e001d70a22c8ff919caee69435376bccce79
# Successfully built paho-mqtt
# ...
#   Running setup.py develop for donkeycar
# ...

# %% [markdown]
# # Create Project
# d2 is the project name and you can rename it with your choice. Make sure if you rename d2 below, that you change all the remaining part of the codes as well in this notebook.

# %%
# !donkey createcar --path /content/d2
# Out:
# using donkey v3.1.1 ...
# Creating car folder: /content/d2
# making dir  /content/d2
# Creating data & model folders.
# making dir  /content/d2/models
# making dir  /content/d2/data
# making dir  /content/d2/logs
# Copying car application template: complete
# Copying car config defaults. Adjust these before starting your car.
# Copying train script. Adjust these before starting your car.
# Copying my car config overrides
# Donkey setup complete.

# %% [markdown]
# #Prepare the data: upload data.zip and unzip data
# When the following code is executed, a file upload form appears. Upload data.zip.
# The data.zip file is the folder found from your raspberry pi. Copy the data to your pc/mac and then zip it as data.zip
# data.zip is uploaded under / content. Move to /content/d2/data using the mv command and unzip it.

# %% [markdown]
# <img src="https://i1.wp.com/techwithsach.com/wp-content/uploads/2019/06/Screen-Shot-2019-06-29-at-7.43.15-PM.png?fit=1024%2C658&amp;ssl=1" alt="Train an autopilot using Colab" class="wp-image-872"/>

# %%
import os
from google.colab import files

if(os.path.exists("/content/data.zip")):
   os.remove("/content/data.zip")
if(os.path.exists("/content/d2/data/data.zip")):
   os.remove("/content/d2/data/data.zip")

# %%
# !pip install -U -q PyDrive

# %%
##colab 마운팅

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
##구글 드라이브에서 공유가능한 링크 가져오기 url에서 파일 id가 있음. 3번째 줄에서 작은따옴표 안에 놓기.

file_id = '1P7usA7DAzOJ7A4YzSpBHddSGFtRqeMcN' # URL id. 
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/d2/data/data.zip')

# %%
# !ls #to verify content
# Out:
# d2  donkey  sample_data

# %%
# %cd /content/d2/data
# Out:
# /content/d2/data

# %%
# !ls
# Out:
# data.zip

# %%
# %cd /content/d2/data/
# !unzip -o data.zip
# Out:
# /content/d2/data
# Archive:  data.zip
#   inflating: tub_145_20-01-11/10000_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10001_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10002_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10003_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10004_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10005_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10006_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10007_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10008_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10009_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/1000_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10010_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10011_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10012_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10013_cam-image_array_.jpg
#   inflating: tub_145_20-01-11/10014_cam-image_array_.jpg
# ...

# %% [markdown]
# # Clean up your data folder
# make sure you have only the tub folders and its associated images and JSON files.

# %%
# !rm /content/d2/data/data.zip

# %%
ls
# Out:
# tub_145_20-01-11/

# %% [markdown]
# # Train your model

# %% [markdown]
# <img src="https://i2.wp.com/techwithsach.com/wp-content/uploads/2019/06/Donkey-Car-training-using-Google-Colab.png?fit=1024%2C509&amp;ssl=1" alt="Donkey Car training using Google Colab" class="wp-image-879"/>

# %%
# !python /content/d2/manage.py train --model /content/d2/models/mypilot.h5
# Out:
# using donkey v3.1.1 ...
# loading config file: /content/d2/config.py
# loading personal config over-rides
#
# config loaded
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %% [markdown]
# #Copy trained model to the Donkey Car.
# Once the training is complete, you will find the mypilot model file under d2/models/ folder location.
# 1. Download the mypilot file to your PC or Mac.
# 2. Copy the file from your PC or Mac to the Raspberry Pi using Filezilla or scp command.

# %%
# %cd /content/d2/models/
# Out:
# /content/d2/models

# %%
# !ls
# Out:
# mypilot.h5  mypilot.h5_loss_acc_0.054683.png

# %%
## 실행할 필요없음. 코랩 마운팅 하는법.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# # Drive using the Autopilot mode
# Continue to follow the remaining part of the tutorial from **techwithsach.com**
